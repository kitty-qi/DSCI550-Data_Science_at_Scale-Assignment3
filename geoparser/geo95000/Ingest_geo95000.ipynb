# %%
import pandas as pd
import pysolr
import requests
from tqdm.notebook import tqdm

# %%
df = pd.read_csv('combine_rtg.csv')

# %%
df
# Out:
#        Unnamed: 0  Unnamed: 0.1  Story Primary ID       Story ID  \
# 0               0             0            156581  STY1666112066
# 1               1             1            156580  STY1666111954
# 2               2             2            156579  STY1666111923
# 3               3             3            156578  STY1666111798
# 4               4             4            156577  STY1666111463
# ...           ...           ...               ...            ...
# 94995       94995         94995             69290  STY1642159740
# 94996       94996         94996             69289  STY1642159721
# 94997       94997         94997             69288  STY1642159611
# 94998       94998         94998             69287  STY1642159601
# 94999       94999         94999             69286  STY1642159578
#
#        User Primary ID        User ID  Gender  Age  \
# 0                86625  USR1662300553     NaN   12
# 1               119236  USR1665943314     NaN   18
# 2                86566  USR1662294899     NaN   12
# 3                86655  USR1662303432     NaN   12
# 4                 9221  USR1632727815    male   23
# ...                ...            ...     ...  ...
# 94995            21189  USR1642158120     NaN   21
# 94996            21194  USR1642158805  female   18
# 94997            21203  USR1642159306     NaN   21
# 94998            21202  USR1642159269     NaN   22
# 94999            21096  USR1642151996     NaN   19
#
#                                                    Title  \
# 0      Qatar Airways cuts flights to accommodate FIFA...
# 1      Positive thinking does not necessarily mean av...
# 2      FIFA negotiating 'initiatives' for Qatar migra...
# 3      Qatar ready for the World Cup in just over a m...
# 4      Froyo always makes everyone happy, make this h...
# ...                                                  ...
# 94995                                                Bts
# 94996                            I LOVE SHARK TANK INDIA
# 94997                         Patanjali-Good for health.
# 94998                                    Football League
# 94999                  Come back stronger like the waves
#
#                                                Narrative  ...  \
# 0      <p dir="ltr">Qatar Airways&#160;has withdrawn ...  ...
# 1      <p dir="ltr">Positive thinking does not necess...  ...
# 2      <p dir="ltr">FIFA's president sought Monday to...  ...
# 3      <p dir="ltr">Ticket sales for the FIFA World C...  ...
# 4      <p dir="ltr"></p>\r\n<p dir="ltr">Almost all o...  ...
# ...                                                  ...  ...
# 94995                                         Bts j hope  ...
# 94996  It's breathe of fresh air in a polluted enviro...  ...
# 94997  I use this Ayurveda product for boosting my im...  ...
# 94998  Me and my friend playing football inside our c...  ...
# 94999  And now that you don’t have to be perfect, you...  ...
#
#       Public Holiday Or Not Covid Cases Covid Deaths  Covid Tests  \
# 0                      True   1498635.0       4490.0          0.0
# 1                     False    810671.0       2255.0          0.0
# 2                      True   1498635.0       4490.0          0.0
# 3                      True   1498635.0       4490.0          0.0
# 4                     False   1981847.0      31809.0    7878605.0
# ...                     ...         ...          ...          ...
# 94995                 False  14381324.0      33867.0   12939335.0
# 94996                 False  14381324.0      33867.0   12939335.0
# 94997                 False  14381324.0      33867.0   12939335.0
# 94998                 False  14381324.0      33867.0   12939335.0
# 94999                 False  14381324.0      33867.0   12939335.0
#
#        Covid Vaccinations                                      Image Caption  \
# 0              16637213.0         a sign that is on the side of a building .
# 1              12556239.0  a collage of photos of a person holding a pair...
# 2              16637213.0  a red and white fire hydrant sitting on top of...
# 3              16637213.0     a tennis court with a tennis racket and a ball
# 4             132857432.0  a piece of chocolate cake sitting on top of a ...
# ...                   ...                                                ...
# 94995         109788076.0  a woman is taking a picture of herself in a mi...
# 94996         109788076.0             a man holding a frisbee in his hands .
# 94997         109788076.0  a red and white fire hydrant sitting in the mi...
# 94998         109788076.0  a group of people standing on top of a lush gr...
# 94999         109788076.0                       a book and a book on a bed .
#
#                                         Detected Objects  tika_language  \
# 0                          ['street sign', 'scoreboard']             en
# 1                                   ['envelope', 'menu']             en
# 2      ['book jacket, dust cover, dust jacket, dust w...             en
# 3                                     ['dome', 'mosque']             en
# 4                       ['ice cream, icecream', 'dough']             en
# ...                                                  ...            ...
# 94995          ['brassiere, bra, bandeau', 'hair spray']             nl
# 94996  ['web site, website, internet site, site', 'pi...             en
# 94997                          ['pill bottle', 'lotion']             en
# 94998                                   ['croquet ball']             en
# 94999                               ['packet', 'lotion']             en
#
#        google_language                                      rtg_translate
# 0                   en  Qatar Airways has withdrawn flights from 18 de...
# 1                   en  Positive thinking does not necessarily mean av...
# 2                   en  FIFA's president sought Monday to dispell ling...
# 3                   en  Ticket sales for the FIFA World Cup Qatar 2022...
# 4                   en  \r\nAlmost all of us is a fan of ice creams, f...
# ...                ...                                                ...
# 94995               nl                                             i hope
# 94996               en  It's breathe of fresh air in a polluted enviro...
# 94997               en  I use this Ayurveda product for boosting my im...
# 94998               en  Me and my friend playing football inside our c...
# 94999               en  And now that you don’t have to be perfect, you...
#
# [95000 rows x 35 columns]

# %%
json_docs = []
doc_id = 0
for index, row in tqdm(df.iterrows()):
    json_doc = {}
    json_doc["text"] = str(row['rtg_translate'])
    #json_doc["text"] = str(row['title']) + ' ' + str(row['abstract'])
    json_doc["id"] = str(doc_id)
    doc_id  = doc_id +1
    #print(json_doc)
    json_docs.append(json_doc)
# Out:
# 0it [00:00, ?it/s]

# %%
core_name = 'geo95000'
# Create a client instance. The timeout and authentication options are not required.
solr = pysolr.Solr('http://localhost:8983/solr/'+core_name, always_commit=True, timeout=10)

# %%
for doc in tqdm(json_docs):
    # How you'd index data.
    solr.add([
        doc
    ])
# Out:
#   0%|          | 0/95000 [00:00<?, ?it/s]
